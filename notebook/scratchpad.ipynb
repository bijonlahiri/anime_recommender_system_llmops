# %%
import pandas as pd
required_columns = {"Name", "Genres", "synopsis"}
df = pd.read_csv("/Users/bijonlahiri/Desktop/llmops_projects/anime_recommender/data/anime_with_synopsis.csv")
print(df.columns)
print(required_columns - set(df.columns))
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'synopsis'], dtype='str')
# set()
